# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df['Location'].nunique()
# Out:
# 49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
print(df.isnull().mean()*100)
sns.kdeplot(df['MinTemp'])
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64
# <Axes: xlabel='MinTemp', ylabel='Density'>

# %%
df = df.drop(['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm'], axis=1)
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %%
df = df.drop(['Date'], axis=1)
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0        Albury     13.4     22.9       0.6           W           44.0
# 1        Albury      7.4     25.1       0.0         WNW           44.0
# 2        Albury     12.9     25.7       0.0         WSW           46.0
# 3        Albury      9.2     28.0       0.0          NE           24.0
# 4        Albury     17.5     32.3       1.0           W           41.0
# ...         ...      ...      ...       ...         ...            ...
# 145455    Uluru      2.8     23.4       0.0           E           31.0
# 145456    Uluru      3.6     25.3       0.0         NNW           22.0
# 145457    Uluru      5.4     26.9       0.0           N           37.0
# 145458    Uluru      7.8     27.0       0.0          SE           28.0
# 145459    Uluru     14.9      NaN       0.0         NaN            NaN
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# ...

# %%
df[df['MinTemp'].isnull()]
# Out:
#        Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 284      Albury      NaN     18.8       NaN           N           31.0
# 444      Albury      NaN     31.2       NaN         ESE           31.0
# 453      Albury      NaN     26.3       NaN          NE           26.0
# 459      Albury      NaN     22.3       0.0          NE           37.0
# 612      Albury      NaN     11.8       NaN         WSW           28.0
# ...         ...      ...      ...       ...         ...            ...
# 144324    Uluru      NaN     27.2       NaN          NE           19.0
# 144325    Uluru      NaN     29.1       NaN         ESE           24.0
# 144326    Uluru      NaN     28.4       NaN           E           24.0
# 144925    Uluru      NaN     39.0       0.0         NaN            NaN
# 144950    Uluru      NaN     35.2       NaN         NaN            NaN
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# ...

# %%
mean = df['MinTemp'].mean()
df['MinTemp'].fillna(mean, inplace=True)
df['MinTemp'].isnull().sum()
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/1463496580.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MinTemp'].fillna(mean, inplace=True)
# np.int64(0)

# %%
print(df.isnull().mean()*100)
sns.kdeplot(df['MinTemp'])
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.866905
# Rainfall          2.241853
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64
# <Axes: xlabel='MinTemp', ylabel='Density'>

# %%
df.iloc[444:445]
sns.kdeplot(df['MaxTemp'])
# Out:
# <Axes: xlabel='MaxTemp', ylabel='Density'>

# %%
meanMAX = df['MaxTemp'].mean()
df['MaxTemp'].fillna(meanMAX, inplace=True)
df['MaxTemp'].isnull().sum()
sns.kdeplot(df['MaxTemp'])
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/1715385484.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MaxTemp'].fillna(meanMAX, inplace=True)
# <Axes: xlabel='MaxTemp', ylabel='Density'>

# %%
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          2.241853
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
sns.boxplot(df['MinTemp'])
# Out:
# <Axes: ylabel='MinTemp'>

# %%
sns.boxplot(df['MaxTemp'])
# Out:
# <Axes: ylabel='MaxTemp'>

# %%
print(df.isnull().mean()*100)
sns.kdeplot(df['Rainfall'])
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          2.241853
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64
# <Axes: xlabel='Rainfall', ylabel='Density'>

# %%
med = df['Rainfall'].median()
df['Rainfall'].fillna(med, inplace=True)
print(df.isnull().mean()*100)
sns.kdeplot(df['Rainfall'])
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/2327915905.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rainfall'].fillna(med, inplace=True)
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# ...

# %%
modee = df['WindGustDir'].mode().values[0]
df['WindGustDir'].fillna(modee, inplace=True)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/1055415771.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WindGustDir'].fillna(modee, inplace=True)

# %%
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
newmean = df['WindGustSpeed'].mean()
df['WindGustSpeed'].fillna(newmean, inplace=True)
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/1452007974.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
sns.kdeplot(df['WindGustSpeed'])
# Out:
# <Axes: xlabel='WindGustSpeed', ylabel='Density'>

# %%
winddirmode = df['WindDir9am'].mode().values[0]
df['WindDir9am'].fillna(winddirmode, inplace=True)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/1011248521.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WindDir9am'].fillna(winddirmode, inplace=True)

# %%
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        0.000000
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
winddirrmode = df['WindDir3pm'].mode().values[0]
df['WindDir3pm'].fillna(winddirrmode, inplace=True)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/3415437509.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WindDir3pm'].fillna(winddirrmode, inplace=True)

# %%
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        0.000000
# WindDir3pm        0.000000
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        0.000000
# WindDir3pm        0.000000
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
speedmean = df['WindSpeed9am'].mean()
df['WindSpeed9am'].fillna(speedmean, inplace=True)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/2227076227.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WindSpeed9am'].fillna(speedmean, inplace=True)

# %%
speedmean3 = df['WindSpeed3pm'].mean()
df['WindSpeed3pm'].fillna(speedmean3, inplace=True)
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        0.000000
# WindDir3pm        0.000000
# WindSpeed9am      0.000000
# WindSpeed3pm      0.000000
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/968148088.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
hummean = df['Humidity9am'].mean()
df['Humidity9am'].fillna(hummean, inplace=True)
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        0.000000
# WindDir3pm        0.000000
# WindSpeed9am      0.000000
# WindSpeed3pm      0.000000
# Humidity9am       0.000000
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/2647702023.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
hummean = df['Humidity3pm'].mean()
df['Humidity3pm'].fillna(hummean, inplace=True)
print(df.isnull().mean()*100)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/4277153011.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Humidity3pm'].fillna(hummean, inplace=True)
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        0.000000
# WindDir3pm        0.000000
# WindSpeed9am      0.000000
# WindSpeed3pm      0.000000
# Humidity9am       0.000000
# ...

# %%
presmean = df['Pressure9am'].mean()
df['Pressure9am'].fillna(presmean, inplace=True)
print(df.isnull().mean()*100)
# Out:
# Location          0.000000
# MinTemp           0.000000
# MaxTemp           0.000000
# Rainfall          0.000000
# WindGustDir       0.000000
# WindGustSpeed     0.000000
# WindDir9am        0.000000
# WindDir3pm        0.000000
# WindSpeed9am      0.000000
# WindSpeed3pm      0.000000
# Humidity9am       0.000000
# Humidity3pm       0.000000
# Pressure9am       0.000000
# Pressure3pm      10.331363
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/1673410551.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
presmean = df['Pressure3pm'].mean()
df['Pressure3pm'].fillna(presmean, inplace=True)
print(df.isnull().mean()*100)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/3906444029.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Pressure3pm'].fillna(presmean, inplace=True)
# Location         0.000000
# MinTemp          0.000000
# MaxTemp          0.000000
# Rainfall         0.000000
# WindGustDir      0.000000
# WindGustSpeed    0.000000
# WindDir9am       0.000000
# WindDir3pm       0.000000
# WindSpeed9am     0.000000
# WindSpeed3pm     0.000000
# Humidity9am      0.000000
# Humidity3pm      0.000000
# ...

# %%
tempmean = df['Temp9am'].mean()
df['Temp9am'].fillna(tempmean, inplace=True)
print(df.isnull().mean()*100)
# Out:
# Location         0.000000
# MinTemp          0.000000
# MaxTemp          0.000000
# Rainfall         0.000000
# WindGustDir      0.000000
# WindGustSpeed    0.000000
# WindDir9am       0.000000
# WindDir3pm       0.000000
# WindSpeed9am     0.000000
# WindSpeed3pm     0.000000
# Humidity9am      0.000000
# Humidity3pm      0.000000
# Pressure9am      0.000000
# Pressure3pm      0.000000
# Temp9am          0.000000
# Temp3pm          2.481094
# RainToday        2.241853
# RainTomorrow     2.245978
# dtype: float64
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/3182507609.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
tempmean = df['Temp3pm'].mean()
df['Temp3pm'].fillna(tempmean, inplace=True)
print(df.isnull().mean()*100)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/1880929934.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Temp3pm'].fillna(tempmean, inplace=True)
# Location         0.000000
# MinTemp          0.000000
# MaxTemp          0.000000
# Rainfall         0.000000
# WindGustDir      0.000000
# WindGustSpeed    0.000000
# WindDir9am       0.000000
# WindDir3pm       0.000000
# WindSpeed9am     0.000000
# WindSpeed3pm     0.000000
# Humidity9am      0.000000
# Humidity3pm      0.000000
# ...

# %%
df['RainToday'].fillna('No', inplace=True)
df['RainTomorrow'].fillna('No', inplace=True)
# Out:
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/686765358.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RainToday'].fillna('No', inplace=True)
# /var/folders/ry/l1lpvxp9349bwxvrb422qz940000gn/T/ipykernel_57721/686765358.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
print(df.isnull().mean()*100)
# Out:
# Location         0.0
# MinTemp          0.0
# MaxTemp          0.0
# Rainfall         0.0
# WindGustDir      0.0
# WindGustSpeed    0.0
# WindDir9am       0.0
# WindDir3pm       0.0
# WindSpeed9am     0.0
# WindSpeed3pm     0.0
# Humidity9am      0.0
# Humidity3pm      0.0
# Pressure9am      0.0
# Pressure3pm      0.0
# Temp9am          0.0
# Temp3pm          0.0
# RainToday        0.0
# RainTomorrow     0.0
# dtype: float64

# %%
print((df['Location'].unique()))
# Out:
# ['Albury' 'BadgerysCreek' 'Cobar' 'CoffsHarbour' 'Moree' 'Newcastle'
#  'NorahHead' 'NorfolkIsland' 'Penrith' 'Richmond' 'Sydney' 'SydneyAirport'
#  'WaggaWagga' 'Williamtown' 'Wollongong' 'Canberra' 'Tuggeranong'
#  'MountGinini' 'Ballarat' 'Bendigo' 'Sale' 'MelbourneAirport' 'Melbourne'
#  'Mildura' 'Nhil' 'Portland' 'Watsonia' 'Dartmoor' 'Brisbane' 'Cairns'
#  'GoldCoast' 'Townsville' 'Adelaide' 'MountGambier' 'Nuriootpa' 'Woomera'
#  'Albany' 'Witchcliffe' 'PearceRAAF' 'PerthAirport' 'Perth' 'SalmonGums'
#  'Walpole' 'Hobart' 'Launceston' 'AliceSprings' 'Darwin' 'Katherine'
#  'Uluru']

# %%
df['Location'].value_counts()
# Out:
# Location
# Canberra            3436
# Sydney              3344
# Darwin              3193
# Melbourne           3193
# Brisbane            3193
# Adelaide            3193
# Perth               3193
# Hobart              3193
# Albany              3040
# MountGambier        3040
# Ballarat            3040
# Townsville          3040
# GoldCoast           3040
# Cairns              3040
# Launceston          3040
# AliceSprings        3040
# Bendigo             3040
# Albury              3040
# MountGinini         3040
# Wollongong          3040
# Newcastle           3039
# Tuggeranong         3039
# Penrith             3039
# Woomera             3009
# Nuriootpa           3009
# Cobar               3009
# CoffsHarbour        3009
# Moree               3009
# Sale                3009
# PerthAirport        3009
# PearceRAAF          3009
# Witchcliffe         3009
# BadgerysCreek       3009
# Mildura             3009
# NorfolkIsland       3009
# MelbourneAirport    3009
# ...

# %%
df.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0   Albury     13.4     22.9       0.6           W           44.0          W
# 1   Albury      7.4     25.1       0.0         WNW           44.0        NNW
# 2   Albury     12.9     25.7       0.0         WSW           46.0          W
# 3   Albury      9.2     28.0       0.0          NE           24.0         SE
# 4   Albury     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# ...

# %%
X = df.drop(['RainTomorrow'], axis=1)
y = df['RainTomorrow']
X
# Out:
#        Location  MinTemp    MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0        Albury     13.4  22.900000       0.6           W       44.00000
# 1        Albury      7.4  25.100000       0.0         WNW       44.00000
# 2        Albury     12.9  25.700000       0.0         WSW       46.00000
# 3        Albury      9.2  28.000000       0.0          NE       24.00000
# 4        Albury     17.5  32.300000       1.0           W       41.00000
# ...         ...      ...        ...       ...         ...            ...
# 145455    Uluru      2.8  23.400000       0.0           E       31.00000
# 145456    Uluru      3.6  25.300000       0.0         NNW       22.00000
# 145457    Uluru      5.4  26.900000       0.0           N       37.00000
# 145458    Uluru      7.8  27.000000       0.0          SE       28.00000
# 145459    Uluru     14.9  23.221348       0.0           W       40.03523
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# ...

# %%
y.value_counts()
# Out:
# RainTomorrow
# No     113583
# Yes     31877
# Name: count, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size= 0.25, random_state=42)
transformer = ColumnTransformer(transformers=[('tnf1', OneHotEncoder(sparse_output=False, drop='first'), ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']),
                                              ],remainder='passthrough')
X_train = transformer.fit_transform(X_train)
X_test = transformer.transform(X_test)

# %%
X_train
# Out:
# array([[   0. ,    0. ,    0. , ..., 1012.9,   17. ,   19.8],
#        [   0. ,    0. ,    0. , ..., 1009.4,   27. ,   26.4],
#        [   0. ,    0. ,    0. , ..., 1021.5,   13.6,   16.9],
#        ...,
#        [   0. ,    0. ,    0. , ..., 1019.6,   13.7,   21.2],
#        [   0. ,    0. ,    0. , ...,  990.9,   14.1,   13.6],
#        [   0. ,    0. ,    0. , ..., 1005.1,   30.1,   33.9]])

# %%
X_test
# Out:
# array([[   0. ,    0. ,    0. , ..., 1003.7,   17.3,   17.6],
#        [   0. ,    0. ,    0. , ..., 1009. ,   16.9,   25.9],
#        [   0. ,    0. ,    0. , ..., 1003.4,   24.2,   27.2],
#        ...,
#        [   0. ,    0. ,    0. , ..., 1020.4,   18.1,   22.9],
#        [   0. ,    0. ,    0. , ..., 1011.6,   25. ,   34.3],
#        [   0. ,    0. ,    0. , ..., 1015.4,   23.1,   23.6]])

# %%
X_train.shape
# Out:
# (109095, 106)

# %%
X_test.shape
# Out:
# (36365, 106)

# %%
le = LabelEncoder()
Y_train = le.fit_transform(Y_train)
Y_test = le.transform(Y_test)

# %%
Y_train.shape
# Out:
# (109095,)

# %%
Y_test.shape
# Out:
# (36365,)

# %%
X_train.shape
# Out:
# (109095, 106)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=250)
lr.fit(X_train, Y_train)
# Out:
# /Users/shivii2526/Desktop/logisticregrrain/.venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=250)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
cf = confusion_matrix(y_true=Y_test, y_pred=y_pred)
accuracy_score(y_true=Y_test, y_pred=y_pred)
disp = ConfusionMatrixDisplay(cf)
disp.plot()
plt.show()
